# %% [markdown]
# <a href="https://colab.research.google.com/github/betty6you/TeamProject_group6/blob/main/Vacc_Dose_TM_Bi_gram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the processed vaccination file
import pandas as pd
df=pd.read_csv(r"ProcessedCovidVaccineReact.csv")
df
# Out:
#                   TweetDate  ...         Country
# 0       2021-03-17 23:59:34  ...         Unknown
# 1       2021-03-17 23:59:20  ...         Unknown
# 2       2021-03-17 23:58:31  ...  United Kingdom
# 3       2021-03-17 23:58:03  ...       Australia
# 4       2021-03-17 23:57:37  ...          Brazil
# ...                     ...  ...             ...
# 352017  2021-04-03 18:39:22  ...          Canada
# 352018  2021-04-03 18:39:13  ...   United States
# 352019  2021-04-03 18:39:04  ...           Japan
# 352020  2021-04-03 18:38:54  ...         Ireland
# 352021  2021-04-03 18:38:54  ...           India
#
# [352022 rows x 7 columns]

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> all
#     Downloading collection 'all'
#        |
#        | Downloading package abc to /root/nltk_data...
#        |   Unzipping corpora/abc.zip.
#        | Downloading package alpino to /root/nltk_data...
#        |   Unzipping corpora/alpino.zip.
#        | Downloading package biocreative_ppi to /root/nltk_data...
#        |   Unzipping corpora/biocreative_ppi.zip.
#        | Downloading package brown to /root/nltk_data...
#        |   Unzipping corpora/brown.zip.
#        | Downloading package brown_tei to /root/nltk_data...
#        |   Unzipping corpora/brown_tei.zip.
#        | Downloading package cess_cat to /root/nltk_data...
#        |   Unzipping corpora/cess_cat.zip.
#        | Downloading package cess_esp to /root/nltk_data...
#        |   Unzipping corpora/cess_esp.zip.
#        | Downloading package chat80 to /root/nltk_data...
#        |   Unzipping corpora/chat80.zip.
#        | Downloading package city_database to /root/nltk_data...
#        |   Unzipping corpora/city_database.zip.
#        | Downloading package cmudict to /root/nltk_data...
#        |   Unzipping corpora/cmudict.zip.
#        | Downloading package comparative_sentences to
#        |     /root/nltk_data...
#        |   Unzipping corpora/comparative_sentences.zip.
#        | Downloading package comtrans to /root/nltk_data...
#        | Downloading package conll2000 to /root/nltk_data...
#        |   Unzipping corpora/conll2000.zip.
#        | Downloading package conll2002 to /root/nltk_data...
#        |   Unzipping corpora/conll2002.zip.
#        | Downloading package conll2007 to /root/nltk_data...
#        | Downloading package crubadan to /root/nltk_data...
#        |   Unzipping corpora/crubadan.zip.
#        | Downloading package dependency_treebank to /root/nltk_data...
#        |   Unzipping corpora/dependency_treebank.zip.
#        | Downloading package dolch to /root/nltk_data...
#        |   Unzipping corpora/dolch.zip.
#        | Downloading package europarl_raw to /root/nltk_data...
#        |   Unzipping corpora/europarl_raw.zip.
#        | Downloading package floresta to /root/nltk_data...
#        |   Unzipping corpora/floresta.zip.
#        | Downloading package framenet_v15 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v15.zip.
#        | Downloading package framenet_v17 to /root/nltk_data...
#        |   Unzipping corpora/framenet_v17.zip.
#        | Downloading package gazetteers to /root/nltk_data...
#        |   Unzipping corpora/gazetteers.zip.
#        | Downloading package genesis to /root/nltk_data...
#        |   Unzipping corpora/genesis.zip.
#        | Downloading package gutenberg to /root/nltk_data...
#        |   Unzipping corpora/gutenberg.zip.
#        | Downloading package ieer to /root/nltk_data...
#        |   Unzipping corpora/ieer.zip.
#        | Downloading package inaugural to /root/nltk_data...
#        |   Unzipping corpora/inaugural.zip.
#        | Downloading package indian to /root/nltk_data...
#        |   Unzipping corpora/indian.zip.
#        | Downloading package jeita to /root/nltk_data...
#        | Downloading package kimmo to /root/nltk_data...
#        |   Unzipping corpora/kimmo.zip.
#        | Downloading package knbc to /root/nltk_data...
#        | Downloading package lin_thesaurus to /root/nltk_data...
#        |   Unzipping corpora/lin_thesaurus.zip.
#        | Downloading package mac_morpho to /root/nltk_data...
#        |   Unzipping corpora/mac_morpho.zip.
#        | Downloading package machado to /root/nltk_data...
#        | Downloading package masc_tagged to /root/nltk_data...
#        | Downloading package moses_sample to /root/nltk_data...
#        |   Unzipping models/moses_sample.zip.
#        | Downloading package movie_reviews to /root/nltk_data...
#        |   Unzipping corpora/movie_reviews.zip.
#        | Downloading package names to /root/nltk_data...
#        |   Unzipping corpora/names.zip.
#        | Downloading package nombank.1.0 to /root/nltk_data...
#        | Downloading package nps_chat to /root/nltk_data...
#        |   Unzipping corpora/nps_chat.zip.
#        | Downloading package omw to /root/nltk_data...
#        |   Unzipping corpora/omw.zip.
#        | Downloading package opinion_lexicon to /root/nltk_data...
#        |   Unzipping corpora/opinion_lexicon.zip.
#        | Downloading package paradigms to /root/nltk_data...
#        |   Unzipping corpora/paradigms.zip.
#        | Downloading package pil to /root/nltk_data...
#        |   Unzipping corpora/pil.zip.
#        | Downloading package pl196x to /root/nltk_data...
#        |   Unzipping corpora/pl196x.zip.
#        | Downloading package ppattach to /root/nltk_data...
#        |   Unzipping corpora/ppattach.zip.
#        | Downloading package problem_reports to /root/nltk_data...
#        |   Unzipping corpora/problem_reports.zip.
#        | Downloading package propbank to /root/nltk_data...
#        | Downloading package ptb to /root/nltk_data...
#        |   Unzipping corpora/ptb.zip.
#        | Downloading package product_reviews_1 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_1.zip.
#        | Downloading package product_reviews_2 to /root/nltk_data...
#        |   Unzipping corpora/product_reviews_2.zip.
#        | Downloading package pros_cons to /root/nltk_data...
#        |   Unzipping corpora/pros_cons.zip.
#        | Downloading package qc to /root/nltk_data...
#        |   Unzipping corpora/qc.zip.
#        | Downloading package reuters to /root/nltk_data...
#        | Downloading package rte to /root/nltk_data...
#        |   Unzipping corpora/rte.zip.
#        | Downloading package semcor to /root/nltk_data...
#        | Downloading package senseval to /root/nltk_data...
#        |   Unzipping corpora/senseval.zip.
#        | Downloading package sentiwordnet to /root/nltk_data...
#        |   Unzipping corpora/sentiwordnet.zip.
#        | Downloading package sentence_polarity to /root/nltk_data...
#        |   Unzipping corpora/sentence_polarity.zip.
#        | Downloading package shakespeare to /root/nltk_data...
#        |   Unzipping corpora/shakespeare.zip.
#        | Downloading package sinica_treebank to /root/nltk_data...
#        |   Unzipping corpora/sinica_treebank.zip.
#        | Downloading package smultron to /root/nltk_data...
#        |   Unzipping corpora/smultron.zip.
#        | Downloading package state_union to /root/nltk_data...
#        |   Unzipping corpora/state_union.zip.
#        | Downloading package stopwords to /root/nltk_data...
#        |   Unzipping corpora/stopwords.zip.
#        | Downloading package subjectivity to /root/nltk_data...
#        |   Unzipping corpora/subjectivity.zip.
#        | Downloading package swadesh to /root/nltk_data...
#        |   Unzipping corpora/swadesh.zip.
#        | Downloading package switchboard to /root/nltk_data...
#        |   Unzipping corpora/switchboard.zip.
#        | Downloading package timit to /root/nltk_data...
#        |   Unzipping corpora/timit.zip.
#        | Downloading package toolbox to /root/nltk_data...
#        |   Unzipping corpora/toolbox.zip.
#        | Downloading package treebank to /root/nltk_data...
#        |   Unzipping corpora/treebank.zip.
#        | Downloading package twitter_samples to /root/nltk_data...
#        |   Unzipping corpora/twitter_samples.zip.
#        | Downloading package udhr to /root/nltk_data...
#        |   Unzipping corpora/udhr.zip.
#        | Downloading package udhr2 to /root/nltk_data...
#        |   Unzipping corpora/udhr2.zip.
#        | Downloading package unicode_samples to /root/nltk_data...
#        |   Unzipping corpora/unicode_samples.zip.
#        | Downloading package universal_treebanks_v20 to
#        |     /root/nltk_data...
#        | Downloading package verbnet to /root/nltk_data...
#        |   Unzipping corpora/verbnet.zip.
#        | Downloading package verbnet3 to /root/nltk_data...
#        |   Unzipping corpora/verbnet3.zip.
#        | Downloading package webtext to /root/nltk_data...
#        |   Unzipping corpora/webtext.zip.
#        | Downloading package wordnet to /root/nltk_data...
#        |   Unzipping corpora/wordnet.zip.
#        | Downloading package wordnet_ic to /root/nltk_data...
#        |   Unzipping corpora/wordnet_ic.zip.
#        | Downloading package words to /root/nltk_data...
#        |   Unzipping corpora/words.zip.
#        | Downloading package ycoe to /root/nltk_data...
#        |   Unzipping corpora/ycoe.zip.
#        | Downloading package rslp to /root/nltk_data...
#        |   Unzipping stemmers/rslp.zip.
#        | Downloading package maxent_treebank_pos_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
#        | Downloading package universal_tagset to /root/nltk_data...
#        |   Unzipping taggers/universal_tagset.zip.
#        | Downloading package maxent_ne_chunker to /root/nltk_data...
#        |   Unzipping chunkers/maxent_ne_chunker.zip.
#        | Downloading package punkt to /root/nltk_data...
#        |   Unzipping tokenizers/punkt.zip.
#        | Downloading package book_grammars to /root/nltk_data...
#        |   Unzipping grammars/book_grammars.zip.
#        | Downloading package sample_grammars to /root/nltk_data...
#        |   Unzipping grammars/sample_grammars.zip.
#        | Downloading package spanish_grammars to /root/nltk_data...
#        |   Unzipping grammars/spanish_grammars.zip.
#        | Downloading package basque_grammars to /root/nltk_data...
#        |   Unzipping grammars/basque_grammars.zip.
#        | Downloading package large_grammars to /root/nltk_data...
#        |   Unzipping grammars/large_grammars.zip.
#        | Downloading package tagsets to /root/nltk_data...
#        |   Unzipping help/tagsets.zip.
#        | Downloading package snowball_data to /root/nltk_data...
#        | Downloading package bllip_wsj_no_aux to /root/nltk_data...
#        |   Unzipping models/bllip_wsj_no_aux.zip.
#        | Downloading package word2vec_sample to /root/nltk_data...
#        |   Unzipping models/word2vec_sample.zip.
#        | Downloading package panlex_swadesh to /root/nltk_data...
#        | Downloading package mte_teip5 to /root/nltk_data...
#        |   Unzipping corpora/mte_teip5.zip.
#        | Downloading package averaged_perceptron_tagger to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger.zip.
#        | Downloading package averaged_perceptron_tagger_ru to
#        |     /root/nltk_data...
#        |   Unzipping taggers/averaged_perceptron_tagger_ru.zip.
#        | Downloading package perluniprops to /root/nltk_data...
#        |   Unzipping misc/perluniprops.zip.
#        | Downloading package nonbreaking_prefixes to
#        |     /root/nltk_data...
#        |   Unzipping corpora/nonbreaking_prefixes.zip.
#        | Downloading package vader_lexicon to /root/nltk_data...
#        | Downloading package porter_test to /root/nltk_data...
#        |   Unzipping stemmers/porter_test.zip.
#        | Downloading package wmt15_eval to /root/nltk_data...
#        |   Unzipping models/wmt15_eval.zip.
#        | Downloading package mwa_ppdb to /root/nltk_data...
#        |   Unzipping misc/mwa_ppdb.zip.
#        |
#      Done downloading collection all
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
# Importing packages
import pandas as pd
from gensim.models import Phrases
from gensim import corpora, models
from nltk.tokenize import word_tokenize 
tokens=[]
bigram = Phrases()

# Iterating through cleaned tweets
for a in df["CleanedTweet"]:
  try:
    if pd.isnull(a) or float(a):
      tokens.append("")
  except ValueError:
# Converting into tokens   
      tokens.append(word_tokenize(a))

# Calling bi-grams API to fetch the bi-grams
bigram_data = models.Phrases(tokens, min_count=30)
bigrams_mod_val = models.phrases.Phraser(bigram_data)

# %%
import operator
dictionary={}
count=0
bigrams=[]
# Creating the dictionary as key value pairs for each bi and its corresponding frequency count
for id in range(len(tokens)):
    for token in bigrams_mod_val[tokens[id]]:
        if '_' in token:
          bigrams.append(token)
          tokens[id].append(token)
# Setting key value dictionary           
for keyVal in bigrams:
  if keyVal in dictionary:
    dictionary[keyVal]+=1
  else:
    dictionary[keyVal]=1

# Returns the final list of bigram Map.    
data= sorted(dictionary.items(),key=operator.itemgetter(1),reverse=True)

# %%
data[:30000]
# Out:
# [('first_dose', 5608),
#  ('fully_vaccinated', 5521),
#  ('anniversary_im', 4530),
#  ('see_safe', 4528),
#  ('ichaydon_year', 4523),
#  ('ago_tried', 4523),
#  ('two_doses', 4309),
#  ('mrna_vaccine', 4256),
#  ('vaccines_pfizer', 4130),
#  ('vaccinated_httpstco', 4126),
#  ('moderna_vaccinessavelives', 4121),
#  ('side_effects', 4102),
#  ('hotvickkrishna_need', 4092),
#  ('second_dose', 3832),
#  ('life_saving', 3428),
#  ('slots_ca', 3336),
#  ('trump_would', 3327),
#  ('would_imagine', 3320),
#  ('davidmweissman_never', 3319),
#  ('leaving_maga', 3319),
#  ('ending_support', 3319),
#  ('million_doses', 2620),
#  ('cvs_locations', 2329),
#  ('blood_clots', 2208),
#  ('jab_job', 2167),
#  ('companies_also', 2069),
#  ('berniespofforth_implementing', 2068),
#  ('policy_new', 2068),
#  ('zealand_pm', 2068),
#  ('outlines_private', 2068),
#  ('obliged_ens', 2068),
#  ('appointments_available', 2062),
#  ('johnson_amp', 1967),
#  ('rite_aids', 1949),
#  ('emas_safety', 1947),
#  ('donut_krispykreme', 1944),
#  ('committee_prac', 1939),
#  ('fucking_year', 1928),
#  ('maryltrump_long', 1926),
#  ('doses_administered', 1738),
#  ('received_first', 1732),
#  ('every_indian', 1620),
#  ('amp_wants', 1620),
#  ('safe_life', 1604),
#  ('rahulgandhi_ridiculous', 1599),
#  ('debate_needs', 1599),
#  ('deserves_chance', 1599),
#  ('cant_wait', 1520),
#  ('outweigh_risks', 1451),
#  ('astrazeneca_still', 1406),
#  ('concludes_benefits', 1395),
#  ('slots_va', 1256),
#  ('covaxin_capacity', 1192),
#  ('per_annum', 1187),
#  ('making_one', 1187),
#  ('next_week', 1186),
#  ('meghupdates_bharat', 1186),
#  ('biotech_ramps', 1186),
#  ('largest_manufacturer', 1186),
#  ('well_done', 1149),
#  ('doses_uk', 1143),
#  ('one_step', 1103),
#  ('vaxhunterscan_hotspot', 1078),
#  ('public_health', 1053),
#  ('make_sure', 1015),
#  ('wear_mask', 1007),
#  ('vaxhunterscan_toronto', 971),
#  ('vaxhunterscan_urgent', 953),
#  ('shoppers_drug', 942),
#  ('reminder_eu', 937),
#  ('richardgcorbett_marr', 936),
#  ('test_positivity', 929),
#  ('pharmacies_per', 912),
#  ('amitaryamd_kingston', 911),
#  ('people_offering', 911),
#  ('brampton_wher', 911),
#  ('years_age', 898),
#  ('safe_effective', 882),
#  ('years_old', 877),
#  ('mass_vaccination', 872),
#  ('take_cant', 862),
#  ('horrible_garbage', 861),
#  ('believe_theatlantic', 861),
#  ('dont_know', 853),
#  ('medical_information', 848),
#  ('nobody_elses', 836),
#  ('choose_vaccination', 834),
#  ('lockdownno_whether', 829),
#  ('tripleh_shot', 787),
#  ('progress_dose', 781),
#  ('book_appointment', 779),
#  ('thank_president', 772),
#  ('doses_haj', 766),
#  ('committee_india', 766),
#  ('ps_adhardocument', 766),
#  ('took_first', 763),
#  ('without_two', 762),
#  ('meghupdates_haj', 761),
#  ('safeways_show', 760),
#  ('loved_ones', 752),
#  ('im_excited', 751),
#  ('drharshvardhan_largestvaccinedrive', 748),
#  ('younger_people', 742),
#  ('follow_retweet', 739),
#  ('made_serum', 735),
#  ('vaccine_treat', 725),
#  ('put_perspective', 724),
#  ('vaccine_passports', 721),
#  ('hug_please', 721),
#  ('announced_april', 721),
#  ('iamwandasykes_fully', 720),
#  ('vaccinated_rejuvenated', 720),
#  ('drericding_breakingdue', 719),
#  ('surging_cases', 719),
#  ('india_frozen', 719),
#  ('major_exports', 719),
#  ('good_news', 718),
#  ('like_free', 718),
#  ('entry_win', 713),
#  ('two_canon', 713),
#  ('month_ago', 710),
#  ('powershot_winner', 710),
#  ('risk_az', 698),
#  ('vaccine_expiring', 695),
#  ('okoch_safety', 695),
#  ('mart_bloor', 692),
#  ('tomorrow_eod', 692),
#  ('waste_administer', 692),
#  ('year_old', 691),
#  ('trial_us', 683),
#  ('closer_getting', 676),
#  ('back_things', 674),
#  ('get_sick', 667),
#  ('past_months', 666),
#  ('irelandvaccine_dose', 664),
#  ('effects_blood', 663),
#  ('peru_chile', 662),
#  ('drericding_blood', 661),
#  ('clot_riskin', 661),
#  ('clots_observ', 661),
#  ('vaccination_centre', 660),
#  ('ive_missed', 658),
#  ('los_angeles', 655),
#  ('back_normal', 651),
#  ('providing_vaccines', 645),
#  ('stephmcmahon_officially', 641),
#  ('vaccination_centres', 632),
#  ('great_news', 631),
#  ('sore_arm', 629),
#  ('feel_like', 627),
#  ('st_vincent', 625),
#  ('last_week', 620),
#  ('cruise_ships', 614),
#  ('dont_want', 602),
#  ('need_evacuating', 601),
#  ('volcano_erupted', 601),
#  ('nearby_islands', 601),
#  ('berniespofforth_desperate', 600),
#  ('gon_na', 599),
#  ('let_us', 598),
#  ('joe_biden', 595),
#  ('review_astrazeneca', 594),
#  ('slots_md', 587),
#  ('health_care', 583),
#  ('drericding_horrible', 583),
#  ('published_garbage', 583),
#  ('true_extre', 583),
#  ('new_cases', 581),
#  ('virginia_beach', 579),
#  ('night_covid', 570),
#  ('stark_contrast', 570),
#  ('vaccineswork_coronavirus', 569),
#  ('er_last', 569),
#  ('drkhaldun_worked', 568),
#  ('hospitalized_sprea', 568),
#  ('datadrivenmd_age', 566),
#  ('though_deaths', 566),
#  ('california_latinos', 566),
#  ('theyve_disproportionat', 566),
#  ('join_us', 565),
#  ('youre_eligible', 565),
#  ('works_pfizer', 565),
#  ('hotvickkrishna_mrna', 564),
#  ('vaccine_modernapfizer', 564),
#  ('naheedd_red', 563),
#  ('dots_pharmacies', 563),
#  ('red_blank', 563),
#  ('spot_torontos', 563),
#  ('northwest_corner', 563),
#  ('one_areas', 563),
#  ('hardest_hi', 563),
#  ('doses_freezers', 560),
#  ('deadly_virus', 554),
#  ('social_media', 553),
#  ('age_eligible', 551),
#  ('looks_like', 549),
#  ('first_lady', 549),
#  ('looking_forward', 536),
#  ('last_year', 528),
#  ('blood_clot', 526),
#  ('two_weeks', 523),
#  ('beverly_hills', 518),
#  ('palm_springs', 515),
#  ('davidmweissman_good', 515),
#  ('side_effect', 509),
#  ('make_appointment', 509),
#  ('made_china', 507),
#  ('via_youtube', 505),
#  ('eligible_receive', 504),
#  ('beach_virginia', 504),
#  ('north_korea', 502),
#  ('myanmar_infected', 500),
#  ('bill_gates', 498),
#  ('stay_safe', 498),
#  ('essential_workers', 497),
#  ('every_person', 497),
#  ('minaunghlaing_whats', 497),
#  ('administered_million', 495),
#  ('healthcare_workers', 494),
#  ('pfizer_moderna', 494),
#  ('every_day', 491),
#  ('ontario_needs', 490),
#  ('downey_el', 486),
#  ('immune_system', 482),
#  ('national_security', 482),
#  ('new_york', 482),
#  ('vaxhunterscan_ca', 482),
#  ('place_empty', 482),
#  ('bring_vaccines', 481),
#  ('safety_committee', 481),
#  ('awkwardgirlla_alert', 480),
#  ('im_cal', 480),
#  ('state_la', 480),
#  ('given_na', 480),
#  ('house_nairobi', 479),
#  ('took_state', 478),
#  ('covaxin_increased', 473),
#  ('last_night', 471),
#  ('country_administer', 470),
#  ('starting_april', 466),
#  ('spreading_false', 463),
#  ('cr_doses', 463),
#  ('sputnik_v', 462),
#  ('doctors_vaccinate', 460),
#  ('equip_family', 459),
#  ('take_care', 458),
#  ('account_hamidmirpak', 458),
#  ('vaxhunterscan_bc', 457),
#  ('astra_zeneca', 455),
#  ('uhuru_kenyatta', 455),
#  ('margaret_kenyatta', 455),
#  ('protect_family', 451),
#  ('press_briefing', 451),
#  ('arising_vaccine', 451),
#  ('refusing_insure', 450),
#  ('please_share', 449),
#  ('newtonclarkeuk_bupa', 449),
#  ('much_worse', 448),
#  ('received_least', 447),
#  ('vaccination_site', 445),
#  ('statehousekenya_president', 443),
#  ('crore_doses', 442),
#  ('went_making', 441),
#  ('april_citizens', 438),
#  ('cheridinovo_breaking', 436),
#  ('nilikm_dearest', 434),
#  ('drericding_watch', 432),
#  ('hesitant_fauci', 432),
#  ('explains_detail', 432),
#  ('decades_research', 432),
#  ('mrna_vac', 432),
#  ('buena_park', 428),
#  ('briefing_emas', 426),
#  ('wave_already', 422),
#  ('anyone_else', 420),
#  ('prime_minister', 420),
#  ('maskupindia_maintain', 415),
#  ('today_request', 414),
#  ('shamikaravi_second', 414),
#  ('first_brace', 414),
#  ('apple_valley', 411),
#  ('thank_science', 409),
#  ('mar_note', 408),
#  ('el_centro', 406),
#  ('postal_codes', 406),
#  ('angeles_lynwood', 405),
#  ('save_lives', 404),
#  ('culver_city', 400),
#  ('azusa_bakersfield', 397),
#  ('come_monday', 397),
#  ('places_jab', 396),
#  ('job_nice', 396),
#  ('work_told', 396),
#  ('herd_immunity', 395),
#  ('one_borisjohnson', 395),
#  ('every_single', 394),
#  ('dont_shop', 389),
#  ('across_country', 387),
#  ('around_preferred', 387),
#  ('health_workers', 385),
#  ('ontarians_please', 385),
#  ('delays_want', 385),
#  ('mygovindia_one', 383),
#  ('drharshvardhan_augmenting', 381),
#  ('supplies_war', 381),
#  ('footing_production', 381),
#  ('cr_dosesmonth', 381),
#  ('put_end', 380),
#  ('far_everyday', 380),
#  ('vaxhunterscan_ab', 378),
#  ('oliviatroye_everything', 378),
#  ('happened_take', 378),
#  ('anything_moment', 378),
#  ('granted_grateful', 378),
#  ('amp_doc', 378),
#  ('alhambra_anaheim', 377),
#  ('stop_spread', 374),
#  ('got_mine', 374),
#  ('thebaumann_miss', 374),
#  ('fact_scottmorrisonmp', 374),
#  ('secured_cheapest', 374),
#  ('australians_https', 374),
#  ('fight_india', 370),
#  ('protecting_nhs', 370),
#  ('year_ago', 369),
#  ('berniespofforth_told', 369),
#  ('nhs_threat', 369),
#  ('covid_elderly', 369),
#  ('amp_vulner', 369),
#  ('miamalan_breaking', 368),
#  ('india_crosses', 368),
#  ('redondo_beach', 365),
#  ('total_administered', 361),
#  ('vaxhunterscan_pharmacy', 361),
#  ('lots_appointments', 360),
#  ('banning_beaumont', 360),
#  ('come_forward', 359),
#  ('cr_stocknearing', 359),
#  ('family_docs', 358),
#  ('historic_moment', 356),
#  ('power_get', 356),
#  ('schedule_appointment', 355),
#  ('fear_mongering', 354),
#  ('mirmakofficial_shame', 352),
#  ('ministers_relatives', 352),
#  ('ministers_using', 352),
#  ('well_planned', 352),
#  ('becomes_fastest', 351),
#  ('let_go', 350),
#  ('convention_center', 349),
#  ('frontline_workers', 348),
#  ('bell_gardens', 348),
#  ('narendramodi_smooth', 347),
#  ('campaign_wow', 347),
#  ('linahidalgotx_part', 346),
#  ('vivekagnihotri_india', 346),
#  ('must_obliged', 346),
#  ('narendramodi_ji', 343),
#  ('drharshvardhan_lets', 341),
#  ('cathedral_city', 341),
#  ('starting_press', 340),
#  ('vaccination_programme', 339),
#  ('trust_science', 339),
#  ('ontario_government', 338),
#  ('long_beach', 335),
#  ('dont_forget', 333),
#  ('twentynine_palms', 332),
#  ('arroyo_grande', 330),
#  ('virus_many', 329),
#  ('people_arent', 328),
#  ('watch_full', 327),
#  ('kimkbaltimore_people', 327),
#  ('tested_posting', 327),
#  ('high_risk', 326),
#  ('agrees_give', 326),
#  ('segundo_fresno', 326),
#  ('cr_cumulative', 326),
#  ('spread_word', 324),
#  ('corona_coronavirus', 323),
#  ('social_distancing', 320),
#  ('education_workers', 320),
#  ('still_waiting', 319),
#  ('coronavaccine_pakistan', 319),
#  ('meghupdates_china', 316),
#  ('refuses_donate', 316),
#  ('payment_collateral', 316),
#  ('gardena_hollywood', 316),
#  ('worlds_largestvaccinedrive', 316),
#  ('ndtv_watch', 316),
#  ('emergency_use', 315),
#  ('palm_desert', 314),
#  ('take_whats', 314),
#  ('baldwin_park', 313),
#  ('vaxhunterscan_ottawa', 313),
#  ('trump_lost', 312),
#  ('offered_safe', 312),
#  ('rolling_hills', 311),
#  ('age_group', 310),
#  ('shop_around', 310),
#  ('reelection_saw', 310),
#  ('inside_fda', 310),
#  ('center_hall', 310),
#  ('emilymiller_fda', 309),
#  ('pfizer_hold', 309),
#  ('deserves_co', 309),
#  ('pharmaceutical_companies', 307),
#  ('eligible_groups', 307),
#  ('nilikm_seriously', 307),
#  ('boomers_dont', 307),
#  ('cases_unusual', 306),
#  ('miamalan_thread', 305),
#  ('vaxhunterscan_scarborough', 305),
#  ('new_yorkers', 304),
#  ('north_york', 304),
#  ('nilikm_ontario', 304),
#  ('bakersfield_baldwin', 303),
#  ('young_people', 302),
#  ('vaxhunterscan_york', 302),
#  ('tested_positive', 301),
#  ('clovis_corona', 301),
#  ('canyon_country', 301),
#  ('family_friends', 300),
#  ('may_suggest', 299),
#  ('newtonclarkeuk_youre', 297),
#  ('youre_annoyed', 297),
#  ('lakh_doses', 296),
#  ('preventing_amp', 296),
#  ('need_send', 295),
#  ('thank_potus', 293),
#  ('second_wave', 293),
#  ('inglewood_los', 293),
#  ('wash_hands', 292),
#  ('dont_understand', 291),
#  ('time_thinking', 291),
#  ('telling_truth', 290),
#  ('friends_family', 290),
#  ('going_wait', 289),
#  ('pm_shri', 289),
#  ('govcanhealth_health', 289),
#  ('health_department', 288),
#  ('inordinate_amount', 288),
#  ('prac_review', 288),
#  ('coronavirus_corona', 287),
#  ('covidnewsbymib_indiafightscorona', 287),
#  ('somebody_spends', 287),
#  ('mpaimd_long', 286),
#  ('inequality_great', 285),
#  ('inequality_lead', 285),
#  ('tragedy_pandemic', 285),
#  ('wearing_mask', 284),
#  ('twittersupport_verified', 284),
#  ('everyone_older', 283),
#  ('hello_twittersafety', 283),
#  ('becomes_first', 282),
#  ('eligible_citizens', 282),
#  ('coming_tuesday', 282),
#  ('never_years', 282),
#  ('news_asked', 281),
#  ('safety_az', 281),
#  ('end_pandemic', 280),
#  ('nilikm_interrupted', 280),
#  ('reporter_live', 280),
#  ('two_jabs', 279),
#  ('drericding_theatlantic', 279),
#  ('published_nonsense', 279),
#  ('vaccination_sites', 278),
#  ('profemilyoster_horrible', 278),
#  ('send_official', 277),
#  ('statement_came', 277),
#  ('nearest_vaccination', 276),
#  ('accepting_walk', 276),
#  ('think_going', 275),
#  ('last_hours', 275),
#  ('made_possible', 275),
#  ('venice_west', 275),
#  ('share_nhs', 274),
#  ('best_source', 274),
#  ('even_though', 274),
#  ('rushed_hospital', 274),
#  ('senior_citizens', 272),
#  ('third_wave', 272),
#  ('best_way', 271),
#  ('feels_like', 271),
#  ('help_protect', 270),
#  ('april_break', 270),
#  ('didnt_follow', 270),
#  ('aged_years', 268),
#  ('vaccinations_delivered', 268),
#  ('thank_narendramodi', 268),
#  ('apr_note', 268),
#  ('knows_old', 268),
#  ('alone_covid', 268),
#  ('today_icu', 268),
#  ('encourage_everyone', 267),
#  ('amitaryamd_schools', 267),
#  ('staying_closed', 267),
#  ('advice_experts', 267),
#  ('believescience_wearamask', 267),
#  ('resistsali_someone', 266),
#  ('lower_azn', 265),
#  ('equity_moral', 264),
#  ('appts_available', 264),
#  ('around_world', 262),
#  ('drericding_johnsonandjohnson', 262),
#  ('perspective_blood', 262),
#  ('lies_none', 262),
#  ('gps_spoken', 262),
#  ('happy_none', 262),
#  ('underlying_health', 261),
#  ('good_morning', 261),
#  ('youre_aged', 261),
#  ('today_salmankhan', 261),
#  ('working_mass', 261),
#  ('clinical_trials', 260),
#  ('persons_years', 260),
#  ('pfizer_sa', 260),
#  ('far_use', 260),
#  ('take_look', 259),
#  ('pm_narendramodi', 259),
#  ('canada_received', 259),
#  ('deptvetaffairs_vaccines', 259),
#  ('around_help', 259),
#  ('ontario_total', 259),
#  ('line_blatant', 259),
#  ('health_minister', 258),
#  ('york_region', 257),
#  ('make_world', 256),
#  ('expand_use', 256),
#  ('submission_pfizerbiontech', 255),
#  ('individuals_yea', 255),
#  ('clinic_patients', 255),
#  ('fact_day', 254),
#  ('govrondesantis_allowed', 254),
#  ('wealthy_communities', 254),
#  ('boris_johnson', 253),
#  ('centre_crush', 253),
#  ('curve_back', 253),
#  ('asked_whether', 253),
#  ('morrison_got', 253),
#  ('lead_world', 252),
#  ('reckon_majority', 252),
#  ('australians_waking', 252),
#  ('howertonsabrina_covering', 252),
#  ('santa_monica', 250),
#  ('basics_keralapolice', 250),
#  ('capacity_looks', 250),
#  ('next_leg', 249),
#  ('annahollandmd_today', 249),
#  ('lets_gear', 248),
#  ('thekeralapolice_get', 248),
#  ('test_talk', 248),
#  ('state_administer', 248),
#  ('drericding_gretathunberg', 247),
#  ('greta_vaccine', 247),
#  ('wear_masks', 246),
#  ('blood_cl', 246),
#  ('safe_place', 244),
#  ('book_online', 244),
#  ('age_category', 244),
#  ('charupragya_maharashtra', 244),
#  ('amp_drharshv', 244),
#  ('light_end', 243),
#  ('every_military', 243),
#  ('beneficiary_early', 243),
#  ('protect_others', 242),
#  ('latest_news', 241),
#  ('granted_janssen', 241),
#  ('manufacture_jampj', 241),
#  ('jab_registration', 241),
#  ('deptofdefense_dod', 241),
#  ('plans_keep', 241),
#  ('commitment_make', 241),
#  ('help_keep', 240),
#  ('higher_risk', 240),
#  ('albert_einstein', 238),
#  ('berniespofforth_important', 237),
#  ('thing_stop', 237),
#  ('questioning_curiosity', 237),
#  ('reason_existing', 237),
#  ('us_enjoy', 237),
#  ('paid_leave', 236),
#  ('largestvaccinedrive_https', 236),
#  ('adverse_events', 235),
#  ('biharhealthdept_bulletin', 235),
#  ('daily_state', 235),
#  ('report_provisional', 235),
#  ('dr_warner', 234),
#  ('chula_vista', 233),
#  ('calling_teachers', 233),
#  ('great_job', 232),
#  ('popup_clinic', 232),
#  ('cause_blood', 232),
#  ('southgate_temecula', 232),
#  ('much_better', 230),
#  ('feeling_great', 230),
#  ('nathanstall_ontario', 230),
#  ('vaxhunterscan_mississauga', 230),
#  ('rancho_cucamonga', 229),
#  ('late_night', 227),
#  ('register_online', 227),
#  ('check_share', 226),
#  ('sharing_false', 226),
#  ('vaccinate_anyone', 226),
#  ('federal_government', 225),
#  ('largestvaccinedrive_shri', 225),
#  ('leadership_honble', 225),
#  ('hours_later', 224),
#  ('rare_blood', 224),
#  ('bjpbiplab_india', 224),
#  ('due_mounting', 224),
#  ('amp_johnson', 223),
#  ('west_hollywood', 223),
#  ('drops_im', 223),
#  ('astrazeneca_friend', 223),
#  ('told_per', 223),
#  ('details_sustainabledevelopment', 223),
#  ('smart_smart', 223),
#  ('sustainability_monitoring', 223),
#  ('low_platelets', 222),
#  ('doug_fords', 222),
#  ('evanlsolomon_happy', 222),
#  ('age_groups', 221),
#  ('dangerous_check', 221),
#  ('measures_could', 221),
#  ('united_states', 220),
#  ('age_born', 220),
#  ('lockdowns_representation', 220),
#  ('failure_implement', 220),
#  ('prevented_drastic', 220),
#  ('amp_harmful', 220),
#  ('least_one', 219),
#  ('coronamemes_covidsecondwave', 219),
#  ('vaxhunterscan_hey', 219),
#  ('today_confused', 219),
#  ('death_rate', 218),
#  ('sonymusicnorth_already', 217),
#  ('rosakoire_get', 217),
#  ('president_biden', 216),
#  ('age_offered', 216),
#  ('vaxhunterscan_etobicoke', 216),
#  ('many_lives', 215),
#  ('certain_states', 215),
#  ('come_convention', 215),
#  ('j_lcmchealth', 215),
#  ('watch_video', 214),
#  ('long_term', 214),
#  ('effective_preventing', 214),
#  ('important_role', 214),
#  ('nolaready_want', 214),
#  ('ins_beinthatnumber', 214),
#  ('drericding_shoot', 214),
#  ('foot_rich', 214),
#  ('countries_much', 214),
#  ('drericding_breakingadults', 214),
#  ('immune_response', 213),
#  ('adverse_reactions', 213),
#  ('health_cause', 213),
#  ('drharshvardhan_hue', 213),
#  ('amp_cry', 213),
#  ('partisanship_union', 213),
#  ('govt_farce', 213),
#  ('attempt_hide', 213),
#  ('single_dose', 212),
#  ('puneethrajkumar_got', 212),
#  ('vaccinated_largestvac', 212),
#  ('toungeincheek_series', 212),
#  ('queens_simp', 212),
#  ('people_simp', 212),
#  ('time_province', 212),
#  ('know_someone', 211),
#  ('naheedd_okay', 211),
#  ('sosaskatchewan_introduced', 211),
#  ('next_weeks', 210),
#  ('social_distance', 210),
#  ('clovis_coachella', 210),
#  ('children_august', 209),
#  ('got_ta', 208),
#  ('tests_positive', 208),
#  ('newport_news', 208),
#  ('given_satisfactory', 208),
#  ('explanation_vaccinating', 208),
#  ('injection_site', 207),
#  ('friday_april', 207),
#  ('fordnation_said', 207),
#  ('bakersfield_bell', 207),
#  ('family_med', 207),
#  ('weve_vaccinate', 207),
#  ('let_know', 206),
#  ('va_facility', 206),
#  ('closer_truth', 206),
#  ('uncover_information', 206),
#  ('ccpvirus_laboratory', 206),
#  ('body_aches', 205),
#  ('ishatreza_note', 205),
#  ('lawrencesellin_day', 205),
#  ('vaxhunterscan_general', 205),
#  ('reminder_pharmacies', 205),
#  ('ontario_location', 205),
#  ('restrictions_looking', 205),
#  ('starting_monday', 204),
#  ('park_camarillo', 204),
#  ('amp_gfarooqi', 204),
#  ('san_diego', 203),
#  ('plan_comes', 203),
#  ('deadder_todays', 203),
#  ('ontario_supply', 203),
#  ('sending_cnic', 202),
#  ('community_members', 202),
#  ('taking_walkins', 202),
#  ('cherylfull_best', 202),
#  ('descriptor_yet', 202),
#  ('torontostar_fordva', 202),
#  ('dutertepalpak_suggestion', 202),
#  ('letlenilead_solution', 202),
#  ('duterteresign_asap', 202),
#  ('everyone_else', 201),
#  ('fresno_gardena', 201),
#  ('mrfrankbaraan_problem', 201),
#  ('votevets_congress', 201),
#  ('recently_passed', 201),
#  ('legislation_clarify', 201),
#  ('emphasize_veteran', 201),
#  ('dr_fauci', 200),
#  ('vaccineswork_vaccinessavelives', 200),
#  ('years_older', 200),
#  ('shots_arms', 199),
#  ('family_members', 199),
#  ('colonial_heights', 199),
#  ('received_firstdose', 199),
#  ('province_announced', 199),
#  ('arm_sore', 198),
#  ('stay_home', 198),
#  ('year_olds', 198),
#  ('primary_care', 198),
#  ('seen_along', 198),
#  ('dr_jalil', 198),
#  ('parker_entering', 198),
#  ('vaxhunterscan_gta', 198),
#  ('number_shoppers', 198),
#  ('drug_marts', 198),
#  ('andrewyang_get', 198),
#  ('vaccination_program', 197),
#  ('find_information', 197),
#  ('social_care', 197),
#  ('major_milestone', 197),
#  ('received_almost', 197),
#  ('bhai_got', 197),
#  ('please_schedule', 197),
#  ('doses_throughout', 197),
#  ('province_arms', 197),
#  ('lilavati_took', 196),
#  ('amp_whet', 196),
#  ('ishatreza_okay', 196),
#  ('per_cent', 195),
#  ('meghasprasad_sallu', 195),
#  ('play_ending', 195),
#  ('vaccines_urgently', 195),
#  ('click_link', 194),
#  ('cowin_portal', 194),
#  ('az_coming', 194),
#  ('contra_costa', 194),
#  ('far_pts', 194),
#  ('confirmed_want', 194),
#  ('stanfordmed_watch', 194),
#  ('aged_care', 193),
#  ('temporary_side', 192),
#  ('register_elderly', 192),
#  ('vaxhunterscan_hearing', 192),
#  ('pregnant_women', 191),
#  ('front_line', 191),
#  ('live_work', 191),
#  ('family_doctors', 191),
#  ('anaheim_bell', 191),
#  ('provide_view', 191),
#  ('chief_minister', 190),
#  ('didnt_feel', 189),
#  ('folks_go', 189),
#  ('busydrt_many', 189),
#  ('finally_alhamdulillah', 189),
#  ('working_hard', 188),
#  ('right_thing', 188),
#  ('tuesday_april', 188),
#  ('im_pro', 188),
#  ('mashwaniazhar_abbu', 188),
#  ('shot_afternoon', 187),
#  ('us_additional', 187),
#  ('mammograms_either', 187),
#  ('weeks_possible', 187),
#  ('hardest_hit', 186),
#  ('many_spots', 186),
#  ('wait_line', 186),
#  ('im_glad', 185),
#  ('felt_like', 185),
#  ('directive_know', 185),
#  ('ogun_state', 185),
#  ('currently_eligible', 184),
#  ('dont_delay', 184),
#  ('pm_modi', 184),
#  ('emer_cooke', 184),
#  ('norfolk_poquoson', 184),
#  ('drmercykorir_new', 184),
#  ('turned_arizona', 184),
#  ('amp_samedaynext', 184),
#  ('days_administer', 184),
#  ('gov_website', 184),
#  ('staff_volunteers', 183),
#  ('needles_palm', 183),
#  ('ryanshead_make', 183),
#  ('mind_doug', 183),
#  ('fema_offered', 183),
#  ('didnt_even', 182),
#  ('oxford_astrazeneca', 182),
#  ('health_condition', 182),
#  ('never_ask', 182),
#  ('shows_good', 182),
#  ('protection_six', 182),
#  ('clots_gist', 182),
#  ('press_memo', 182),
#  ('vaxhunterscan_hamilton', 182),
#  ('one_eva', 182),
#  ('poquoson_portsmouth', 181),
#  ('drericding_least', 181),
#  ('monthspfizer_data', 181),
#  ('vaccines_acquired', 181),
#  ('easiest_way', 180),
#  ('fuck_auspol', 180),
#  ('giving_shots', 178),
#  ('hot_springs', 178),
#  ('nhs_best', 177),
#  ('questions_answered', 177),
#  ('clinical_trial', 176),
#  ('krispy_kreme', 176),
#  ('says_additional', 176),
#  ('good_thing', 175),
#  ('feels_good', 175),
#  ('emas_exec', 175),
#  ('still_doesnt', 175),
#  ('indepth_analysis', 175),
#  ('today_phc', 175),
#  ('know_ton', 175),
#  ('super_eager', 175),
#  ('drkerrynphelps_gp', 175),
#  ('medicare_rebate', 175),
#  ('given_home', 175),
#  ('visit_housebound', 175),
#  ('care_employees', 174),
#  ('okeilewo_abeokuta', 174),
#  ('director_prac', 174),
#  ('concluded_reported', 174),
#  ('jabbed_didnt', 174),
#  ('free_charge', 173),
#  ('park_buena', 173),
#  ('learning_difficulties', 173),
#  ('families_management', 173),
#  ('adelanto_angels', 173),
#  ('tweet_martinkulldorff', 173),
#  ('start_tomorrow', 173),
#  ('feeling_warm', 173),
#  ('world_accept', 173),
#  ('pause_use', 172),
#  ('vkiragandur_hombale', 172),
#  ('committed_wellbeing', 172),
#  ('associates_amp', 172),
#  ('starneelima_salman', 172),
#  ('khan_took', 172),
#  ('believe_affect', 172),
#  ('saw_yo', 172),
#  ('eligible_requested', 172),
#  ('another_popup', 172),
#  ('shoppers_dundas', 172),
#  ('west_north', 172),
#  ('side_btn', 172),
#  ('runnymede_jane', 172),
#  ('az_line', 172),
#  ('arvin_bakersfield', 172),
#  ('shefvaidya_got', 172),
#  ('click_picture', 172),
#  ('longcovid_symptoms', 171),
#  ('big_pharma', 171),
#  ('task_force', 171),
#  ('krutikakuppalli_anyone', 171),
#  ('today_ic', 171),
#  ('journalists_frontline', 171),
#  ('dont_miss', 170),
#  ('hard_work', 170),
#  ('dukhyariuzi_hello', 170),
#  ('twittersafetytwittersupport_verified', 170),
#  ('forehead_freezing', 170),
#  ('past_year', 169),
#  ('european_medicines', 169),
#  ('et_al', 169),
#  ('medical_professionals', 169),
#  ('inviting_community', 169),
#  ('nolaready_starting', 169),
#  ('nsitharaman_india', 169),
#  ('avail_vaccin', 169),
#  ('walk_center', 169),
#  ('circulate_quickly', 168),
#  ('vaccineca_cvs', 168),
#  ('locations_show', 168),
#  ('urges_union', 168),
#  ('inaccurate_claims', 167),
#  ('rollout_canada', 167),
#  ('beacon_hospital', 167),
#  ('government_declare', 167),
#  ('community_center', 166),
#  ('false_information', 166),
#  ('central_government', 166),
#  ('desert_hot', 166),
#  ('largestvaccinedrive_amrutmahotsav', 166),
#  ('indeditorsguild_editors', 166),
#  ('guild_india', 166),
#  ('workers_allowed', 166),
#  ('older_eligible', 165),
#  ('new_variants', 165),
#  ('lets_keep', 165),
#  ('ill_az', 165),
#  ('yucca_valley', 165),
#  ('turn_comes', 164),
#  ('county_residents', 164),
#  ('monica_southgate', 164),
#  ('office_starting', 164),
#  ('patients_al', 164),
#  ('city_industry', 164),
#  ('constitutional_rights', 164),
#  ('mask_mandate', 163),
#  ('record_card', 163),
#  ('nhsengland_youre', 163),
#  ('himantabiswa_took', 163),
#  ('excellence_kagutamuseveni', 163),
#  ('justintrudeau_pattyhajdu', 163),
#  ('high_school', 162),
#  ('havent_even', 162),
#  ('test_positive', 162),
#  ('shipment_az', 162),
#  ('miss_press', 162),
#  ('prac_conclusion', 162),
#  ('steverussell_fedex', 162),
#  ('ground_crews', 162),
#  ('pearson_international', 162),
#  ('airport_unload', 162),
#  ('shipment_three', 162),
#  ('refrigerated_containers', 162),
#  ('canada_rise', 162),
#  ('fall_together', 162),
#  ('share_loan', 162),
#  ('chino_clovis', 161),
#  ('country_return', 161),
#  ('eligible_pops', 161),
#  ('either_support', 161),
#  ('feel_fine', 160),
#  ('louisiana_thing', 160),
#  ('ever_love', 160),
#  ('within_days', 159),
#  ('days_early', 159),
#  ('wanting_open', 159),
#  ('coachella_desert', 159),
#  ('fresno_indio', 159),
#  ('georebekah_louisiana', 159),
#  ('liquor_shots', 159),
#  ('wearing_masks', 158),
#  ('important_message', 158),
#  ('vaccination_rates', 158),
#  ('union_health', 158),
#  ('till_pm', 158),
#  ('postal_code', 158),
#  ('bitch_loudest', 158),
#  ('normal_folks', 158),
#  ('downsview_arena', 158),
#  ('learning_disability', 157),
#  ('appointment_needed', 157),
#  ('private_sector', 157),
#  ('spoke_february', 157),
#  ('south_africa', 156),
#  ('starting_march', 156),
#  ('doesnt_mean', 156),
#  ('ests_santa', 156),
#  ('born_earlier', 156),
#  ('highly_effective', 155),
#  ('arcadia_artesia', 155),
#  ('socofthesacred_holy', 155),
#  ('cow_consistent', 155),
#  ('story_trust', 155),
#  ('breitbart_amp', 155),
#  ('foxnews_increases', 155),
#  ('trust_oth', 155),
#  ('clinic_visitors', 155),
#  ('fresno_hanford', 154),
#  ('blood_clotting', 154),
#  ('feeling_fine', 154),
#  ('went_back', 154),
#  ('working_survival', 154),
#  ('rate_goes', 154),
#  ('temecula_torrance', 154),
#  ('berniespofforth_really', 154),
#  ('come_woman', 154),
#  ('held_care', 154),
#  ('workers_whilst', 154),
#  ('frankgunnphoto_vaccine', 154),
#  ('wadepthealth_starting', 154),
#  ...]

# %%
labels = ['Bigram_Words', 'Frequency']
df = pd.DataFrame.from_records(data[:30000], columns=labels)
df
# Out:
#           Bigram_Words  Frequency
# 0           first_dose       5608
# 1     fully_vaccinated       5521
# 2       anniversary_im       4530
# 3             see_safe       4528
# 4        ichaydon_year       4523
# ...                ...        ...
# 6315         proud_guy          1
# 6316       lungs_lungs          1
# 6317        fyi_hamont          1
# 6318   sames_warehouse          1
# 6319  countrys_medical          1
#
# [6320 rows x 2 columns]

# %%
# Importing libraries for visual word cloud map

import numpy as np
from PIL import Image
import pandas as pd
from os import path
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
# Python program to generate WordCloud for column Bigrams

textData = " ".join(review for review in df.Bigram_Words.astype(str))

# removing stopwords that we want to exclude
stopwords = set(STOPWORDS)
stopwords.update(["hotvickkrishna_need","leaving_maga","cant_wait"])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="black", width=800, height=400).generate(textData)

# Display the generated image matplotlib way:
plt.axis("off")
plt.title("Visual analyzation of all the top extracted meaningful bigrams")
plt.figure( figsize=(40,20))
plt.tight_layout(pad=0)
plt.imshow(wordcloud, interpolation='bilinear')
plt.show()

# %%
# Analysing the bi-grams and manually reading the bi-grams and categorizing them as First Dose , Second Dose and yet to be vaccinated
First_Dose =[ 'first_dose', 'got_first','receives_first','took_first','due_second','single_dose','wearamask_firstdosedone','doses_administered','administering_doses'] # First Dose declaring manually for analysis
Second_Dose =['received_second','second_dose','two_doses'] # Second Dose declaring manually for analysis
Appointments_Scheduled = ['schedule_appointment','appointment_saturday','appointments_newly','appointment_online'] # Scheduled appointments declaring manually for analysis

First_Dose_Count   = df.loc[df['Bigram_Words'].isin(First_Dose), 'Frequency'].sum()
Second_Dose_Count  = df.loc[df['Bigram_Words'].isin(Second_Dose), 'Frequency'].sum()
Appointments_Count = df.loc[df['Bigram_Words'].isin(Appointments_Scheduled), 'Frequency'].sum()

# initialize list of lists
Vaccination_Doses = [['First Dose', First_Dose_Count], ['Second Dose', Second_Dose_Count], ['Appointments Scheduled', Appointments_Count]]
  
# Create the pandas DataFrame
df = pd.DataFrame(Vaccination_Doses, columns = ['Vaccination_Doses', 'Population_Count'])
df['percent_count'] = (df['Population_Count'] / df['Population_Count'].sum()) * 100
percentCount= df['percent_count'].tolist()  
vaccinationDoses= df['Vaccination_Doses'].tolist()
# print dataframe.
df
# Out:
#         Vaccination_Doses  Population_Count  percent_count
# 0              First Dose              8538      48.945196
# 1             Second Dose              8141      46.669342
# 2  Appointments Scheduled               765       4.385462

# %%
from matplotlib import pyplot as plt
# Create a sample dataframe with an text index


plotdata = pd.DataFrame(
    {"Percentage of dosage": percentCount}, 
    index= vaccinationDoses)
# Plot a bar chart
plotdata.plot(kind="bar")

plotdata['Percentage of dosage'].plot(kind="bar", title="")
# Rotate the x-labels by 30 degrees, and keep the text aligned horizontally
plt.xticks(rotation=30, horizontalalignment="center")
plt.title("% of people getting vaccination Dosage results ")
plt.xlabel("Dose details")
plt.ylabel("Percentage of dosage count")
plt.savefig('VaccineDosage.png')
